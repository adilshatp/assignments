# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
airline=pd.read_excel('EastWestAirlines.xlsx',1)
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline.shape
# Out:
# (3999, 12)

# %%
airline.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
airline.dtypes
# Out:
# ID#                  int64
# Balance              int64
# Qual_miles           int64
# cc1_miles            int64
# cc2_miles            int64
# cc3_miles            int64
# Bonus_miles          int64
# Bonus_trans          int64
# Flight_miles_12mo    int64
# Flight_trans_12      int64
# Days_since_enroll    int64
# Award?               int64
# dtype: object

# %%
airline=airline.drop(['ID#'],axis=1)

# %%
airline.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
from sklearn.preprocessing import StandardScaler

# %%
std=StandardScaler()

# %%
airline_std=std.fit_transform(airline)

# %%
airline_std
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
airline_scaled=pd.DataFrame(airline_std,columns=['Balance','Qual_miles','cc1_miles','cc2_miles','cc3_miles','Bonus_miles','Bonus_trans','Flight_miles_12mo','Flight_trans_12','Days_since_enroll','Award?'])

# %%
airline_scaled
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
import scipy.cluster.hierarchy as sch

# %%
dendogram=sch.dendrogram(sch.linkage(airline_scaled,method='single',metric='euclidean'))

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
h_c=AgglomerativeClustering(n_clusters=2,linkage='single')

# %%
y_h_c=h_c.fit_predict(airline_scaled)
y_h_c
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
airline1=airline

# %%
airline1['cluster']=pd.DataFrame(y_h_c)

# %%
airline1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ## kmean

# %%
from sklearn.cluster import KMeans

# %%
x=[]
for i in range(1,11):
    k_airline=KMeans(n_clusters=i,random_state=12)
    k_airline.fit(airline_scaled)
    x.append(k_airline.inertia_)

# %%
plt.plot(range(1,11),x)
plt.title('elbowchart')
plt.xlabel('squarerd error')
plt.ylabel('no of clusters')
# Out:
# Text(0, 0.5, 'no of clusters')

# %%
k_airlines=KMeans(n_clusters=4,random_state=12)
k_airlines.fit(airline_scaled)
# Out:
# KMeans(n_clusters=4, random_state=12)

# %%
kk=k_airlines.labels_

# %%
airline2=airline

# %%
airline2['cluster']=kk

# %%
airline2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline2['cluster'].nunique()
# Out:
# 4

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
d_airline=DBSCAN(eps=0.7,min_samples=6).fit(airline_scaled)

# %%
cluster=d_airline.labels_
cluster
# Out:
# array([0, 0, 0, ..., 5, 0, 0], dtype=int64)

# %%
airline4=airline

# %%
airline4['cluster']=cluster

# %%
airline4
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline4['cluster'].nunique()
# Out:
# 16
